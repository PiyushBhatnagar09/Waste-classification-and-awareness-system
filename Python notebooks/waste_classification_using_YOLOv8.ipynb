# %%
# !nvidia-smi
# Out:
# Fri Nov  8 16:46:03 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME=os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 54.2 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.4/112.6 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# Disk                32.4/112.6 GB
# CPU                 Intel Xeon 2.20GHz
# CPU count           2
# GPU                 Tesla T4, 15102MiB
# GPU count           1
# CUDA                12.1
#
# numpy               ✅ 1.26.4>=1.23.0
# matplotlib          ✅ 3.8.0>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 10.4.0>=7.1.2
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="bYDXVNmFoQT1UIRyos2n")
project = rf.workspace("piyush-bhatnagar-xur76").project("waste-classification-hz9qg")
dataset = project.version(1).download("yolov8")
print(dataset)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Waste-classification-1 in yolov8:: 100%|██████████| 132/132 [00:00<00:00, 155.81it/s]
# ...

# %%
print(dataset.location)
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=30 imgsz=800
# Out:
# d:\PB\FSWD\Waste_Classification_and_Awareness_system\Waste-classification-1
# New https://pypi.org/project/ultralytics/8.3.28 available 😃 Update with 'pip install -U ultralytics'
# train: Scanning D:\PB\FSWD\Waste_Classification_and_Awareness_system\Waste-classification-1\train\labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
# train: Scanning D:\PB\FSWD\Waste_Classification_and_Awareness_system\Waste-classification-1\train\labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
# c:\users\pbpiy\appdata\local\programs\python\python38\lib\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
#
# ...

# %%
from IPython.display import display, Image

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/F1_curve.png', width=600)
# Out:
# /content/drive/My Drive/DataForYoloV8

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/PR_curve.png', width=800)
# Out:
# /content/drive/My Drive/DataForYoloV8

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix_normalized.png', width=800)
# Out:
# /content/drive/My Drive/DataForYoloV8

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=800)
# Out:
# /content/drive/My Drive/DataForYoloV8

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/train_batch2.jpg', width=800)
# Out:
# /content/drive/My Drive/DataForYoloV8

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/My Drive/DataForYoloV8'
# !yolo task=detect mode=val model=/content/drive/MyDrive/DataForYoloV8/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/DataForYoloV8
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 9,829,986 parameters, 0 gradients, 23.4 GFLOPs
# val: Scanning /content/drive/MyDrive/DataForYoloV8/Waste-classification-1/valid/labels.cache... 12 images, 0 backgrounds, 0 corrupt: 100% 12/12 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.01s/it]
#                    all         12         12     0.0119          1       0.79      0.515
#          biodegradable          2          2    0.00123          1      0.995      0.796
#              cardboard          2          2    0.00308          1      0.995      0.697
#                  glass          2          2     0.0204          1      0.745      0.145
# ...

# %%
import imutils
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
image_file = take_photo()

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/drive/MyDrive/DataForYoloV8/runs/detect/train10/weights/best.pt conf=0.25 source=/content/drive/MyDrive/DataForYoloV8/photo.jpg
# Out:
# /content/drive/My Drive/DataForYoloV8
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 9,829,986 parameters, 0 gradients, 23.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/DataForYoloV8/photo.jpg: 608x800 (no detections), 39.6ms
# Speed: 6.8ms preprocess, 39.6ms inference, 52.5ms postprocess per image at shape (1, 3, 608, 800)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !pip install pickle-mixin
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle-mixin: filename=pickle_mixin-1.0.2-py3-none-any.whl size=5990 sha256=5ea657b6a1fa81835a371a36015aacfdfeb791a5662808baaeb8686611324c60
#   Stored in directory: /root/.cache/pip/wheels/3e/c6/e9/d1b0a34e1efc6c3ec9c086623972c6de6317faddb2af0a619c
# Successfully built pickle-mixin
# ...

# %%
import pickle

# Load the trained weights
weights_path = '/content/drive/MyDrive/DataForYoloV8/runs/detect/train10/weights/best.pt'  # Replace with your actual path
# Load and convert the weights to a pickle file
with open(weights_path, 'rb') as f:
    weights = f.read()
pickle.dump(weights, open('yolov8.pkl', 'wb'))

# %%
from google.colab import files
files.download('/content/drive/MyDrive/DataForYoloV8/yolov8.pkl')
